# %%
import numpy as np
from losses import *
from nn import Neural_Net
from layers import *
import random

# %%
def rel_error(x, y):
    """ returns relative error """
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %%
x_train=np.load('x_train.npy').astype(np.float32)
y_train=np.load('y_train.npy')
x_test=np.load('x_test.npy').astype(np.float32)
y_test=np.load('y_test.npy')

idx=np.random.permutation(x_train.shape[0])[:1000]

x_train=x_train[idx]
y_train=y_train[idx]

# %%
x_train=x_train/255.0
x_test=x_test/255.0

# %%
x_train=x_train.reshape(x_train.shape[0],1,1,-1)
x_test=x_test.reshape(x_test.shape[0],1,1,-1)

# %%
nn = Neural_Net()

nn.add_conv(3,1,1,3)
nn.add_relu()
nn.add_fcc(2346,10)

# %%
nn.train(x_train,y_train,0.1,100)
# Out:
# Epoch:  0 / 100 	Loss:  18.583188329484653
#
#
# Epoch:  1 / 100 	Loss:  8.726138812845816
#
#
# Epoch:  2 / 100 	Loss:  2.733157658728236
#
#
# Epoch:  3 / 100 	Loss:  2.3278436816491617
#
#
# Epoch:  4 / 100 	Loss:  2.317428806766663
#
#
# Epoch:  5 / 100 	Loss:  2.3137073595155733
#
#
# Epoch:  6 / 100 	Loss:  2.3106182940843865
#
#
# Epoch:  7 / 100 	Loss:  2.3076822096098364
#
#
# Epoch:  8 / 100 	Loss:  2.304796291611215
#
#
# Epoch:  9 / 100 	Loss:  2.3019308152310076
#
#
# Epoch:  10 / 100 	Loss:  2.299097725954164
#
#
# Epoch:  11 / 100 	Loss:  2.296048678672292
#
#
# Epoch:  12 / 100 	Loss:  2.293129946029267
#
#
# Epoch:  13 / 100 	Loss:  2.2902033720076327
#
#
# Epoch:  14 / 100 	Loss:  2.2872133856984154
#
#
# Epoch:  15 / 100 	Loss:  2.284071046437038
#
#
# Epoch:  16 / 100 	Loss:  2.2807690930355067
#
#
# Epoch:  17 / 100 	Loss:  2.2773711641099696
#
#
# Epoch:  18 / 100 	Loss:  2.2739703468100756
#
#
# Epoch:  19 / 100 	Loss:  2.270376732019963
#
#
# Epoch:  20 / 100 	Loss:  2.266623142758412
#
#
# Epoch:  21 / 100 	Loss:  2.262799423640094
#
#
# Epoch:  22 / 100 	Loss:  2.2590434690108196
#
#
# Epoch:  23 / 100 	Loss:  2.2551711569897246
#
#
# Epoch:  24 / 100 	Loss:  2.25119959423727
#
#
# Epoch:  25 / 100 	Loss:  2.247233465171186
#
#
# Epoch:  26 / 100 	Loss:  2.243352589595799
#
#
# Epoch:  27 / 100 	Loss:  2.239528725322282
#
#
# Epoch:  28 / 100 	Loss:  2.2355921538397587
#
#
# Epoch:  29 / 100 	Loss:  2.2315554802708184
#
#
# Epoch:  30 / 100 	Loss:  2.227370137418134
#
#
# Epoch:  31 / 100 	Loss:  2.2230489614860254
#
#
# Epoch:  32 / 100 	Loss:  2.218562358533734
#
#
# Epoch:  33 / 100 	Loss:  2.213945742369745
#
#
# Epoch:  34 / 100 	Loss:  2.209173068781974
#
#
# Epoch:  35 / 100 	Loss:  2.204183253738535
#
#
# Epoch:  36 / 100 	Loss:  2.198985838441685
#
#
# Epoch:  37 / 100 	Loss:  2.1936712208099998
#
#
# Epoch:  38 / 100 	Loss:  2.1881638298288175
#
#
# Epoch:  39 / 100 	Loss:  2.1824942866956736
#
#
# Epoch:  40 / 100 	Loss:  2.1766816215198
#
#
# Epoch:  41 / 100 	Loss:  2.1706437297091234
#
#
# Epoch:  42 / 100 	Loss:  2.164358799620919
#
#
# Epoch:  43 / 100 	Loss:  2.157807699015083
#
#
# Epoch:  44 / 100 	Loss:  2.1510055528304997
#
#
# Epoch:  45 / 100 	Loss:  2.143910785855301
#
#
# Epoch:  46 / 100 	Loss:  2.136392081151029
#
#
# Epoch:  47 / 100 	Loss:  2.1285852013838777
#
#
# Epoch:  48 / 100 	Loss:  2.1204182042460924
#
#
# Epoch:  49 / 100 	Loss:  2.1118691635756037
#
#
# Epoch:  50 / 100 	Loss:  2.1029525199825434
#
#
# Epoch:  51 / 100 	Loss:  2.0935413383973063
#
#
# Epoch:  52 / 100 	Loss:  2.0837766316060184
#
#
# Epoch:  53 / 100 	Loss:  2.073500119002917
#
#
# Epoch:  54 / 100 	Loss:  2.0624548593832484
#
#
# Epoch:  55 / 100 	Loss:  2.0506321541316916
#
#
# Epoch:  56 / 100 	Loss:  2.0382146646840407
#
#
# Epoch:  57 / 100 	Loss:  2.025266687678389
#
#
# Epoch:  58 / 100 	Loss:  2.0119145069542537
#
#
# Epoch:  59 / 100 	Loss:  1.998127780935758
#
#
# Epoch:  60 / 100 	Loss:  1.983777772254632
#
#
# Epoch:  61 / 100 	Loss:  1.9688970368875367
#
#
# Epoch:  62 / 100 	Loss:  1.9531458318571095
#
#
# Epoch:  63 / 100 	Loss:  1.9368176445026286
#
#
# Epoch:  64 / 100 	Loss:  1.9194354232216209
#
#
# Epoch:  65 / 100 	Loss:  1.9010389199110578
#
#
# Epoch:  66 / 100 	Loss:  1.881318822241204
#
#
# Epoch:  67 / 100 	Loss:  1.859954756536153
#
#
# Epoch:  68 / 100 	Loss:  1.8370148502106034
#
#
# Epoch:  69 / 100 	Loss:  1.812965837381499
#
#
# Epoch:  70 / 100 	Loss:  1.7877038382727273
#
#
# Epoch:  71 / 100 	Loss:  1.7613323571530632
#
#
# Epoch:  72 / 100 	Loss:  1.7344927610363106
#
#
# Epoch:  73 / 100 	Loss:  1.7075496590263848
#
#
# Epoch:  74 / 100 	Loss:  1.6796893283909358
#
#
# Epoch:  75 / 100 	Loss:  1.6510267278218358
#
#
# Epoch:  76 / 100 	Loss:  1.6173145033490546
#
#
# Epoch:  77 / 100 	Loss:  1.6112735523232822
#
#
# Epoch:  78 / 100 	Loss:  1.6564185670980325
#
#
# Epoch:  79 / 100 	Loss:  1.5921406387739239
#
#
# Epoch:  80 / 100 	Loss:  1.5383845630586266
#
#
# Epoch:  81 / 100 	Loss:  1.4981552963631102
#
#
# Epoch:  82 / 100 	Loss:  1.4716974510704415
#
#
# Epoch:  83 / 100 	Loss:  1.5064519074612035
#
#
# Epoch:  84 / 100 	Loss:  1.4612568584703418
#
#
# Epoch:  85 / 100 	Loss:  1.4069623064528742
#
#
# Epoch:  86 / 100 	Loss:  1.3855611010730724
#
#
# Epoch:  87 / 100 	Loss:  1.3780155752707988
#
#
# Epoch:  88 / 100 	Loss:  1.4321005427885805
#
#
# Epoch:  89 / 100 	Loss:  1.3534511466649586
#
#
# Epoch:  90 / 100 	Loss:  1.3028238364129605
#
#
# Epoch:  91 / 100 	Loss:  1.2792063145914008
#
#
# Epoch:  92 / 100 	Loss:  1.287200937120185
#
#
# Epoch:  93 / 100 	Loss:  1.2426767379928765
#
#
# Epoch:  94 / 100 	Loss:  1.217217816032758
#
#
# Epoch:  95 / 100 	Loss:  1.1992130506227472
#
#
# Epoch:  96 / 100 	Loss:  1.203413682126695
#
#
# Epoch:  97 / 100 	Loss:  1.156429726694638
#
#
# Epoch:  98 / 100 	Loss:  1.1487930937435546
#
#
# Epoch:  99 / 100 	Loss:  1.1464688488175991
